# %%
# %matplotlib inline
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
A=np.array([[  1.44300000e+02,   2.35000000e-01,   6.00000000e-03,   6.00000000e-04],
     [  6.21152934e+01,   1.74581460e-01,   2.90161332e-03,   6.00000000e-04],
     [  2.26484707e+02,   2.95418540e-01,   6.00000000e-03,   2.90161332e-04],
     [  1.44300000e+02,   1.74581460e-01,   9.09838668e-03,   9.09838668e-04],
     [  1.44300000e+02,   2.95418540e-01,   2.90161332e-03,   9.09838668e-04],
     [  6.21152934e+01,   2.95418540e-01,   6.00000000e-03,   2.90161332e-04],
     [  2.26484707e+02,   1.74581460e-01,   6.00000000e-03,   2.90161332e-04],
     [  1.44300000e+02,   2.95418540e-01,   9.09838668e-03,   9.09838668e-04],
     [  1.44300000e+02,   2.35000000e-01,   9.09838668e-03,   2.90161332e-04],
     [  2.26484707e+02,   2.35000000e-01,   6.00000000e-03,   9.09838668e-04],
     [  1.44300000e+02,   2.35000000e-01,   2.90161332e-03,   2.90161332e-04],
     [  6.21152934e+01,   2.35000000e-01,   6.00000000e-03,   9.09838668e-04],
     [  6.21152934e+01,   1.74581460e-01,   6.00000000e-03,   2.90161332e-04],
     [  6.21152934e+01,   2.35000000e-01,   9.09838668e-03,   6.00000000e-04],
     [  1.44300000e+02,   1.74581460e-01,   2.90161332e-03,   9.09838668e-04]])

# %%
Output_dissip = [24.8170119614, 23.7770471604, 24.6131673073, 24.9723698096, 24.6920894782, 23.7015914415, 
                 24.6180488646, 25.2502586048, 24.576764997, 25.1656386185, 23.7951837649, 24.540205788, 
                 23.7204920408, 24.514049663, 24.4823906956]
print Output_dissip
# Out:
# [24.8170119614, 23.7770471604, 24.6131673073, 24.9723698096, 24.6920894782, 23.7015914415, 24.6180488646, 25.2502586048, 24.576764997, 25.1656386185, 23.7951837649, 24.540205788, 23.7204920408, 24.514049663, 24.4823906956]

# %%
plt.plot(A[:,0],Output_dissip, 'ro')
#plt.plot(Output_dissip,A[:,0],'ro')
plt.xlabel('plant density')
plt.ylabel('veg_dissip')
plt.show()

# %%
plt.plot(A[:,1],Output_dissip, 'ro')
plt.xlabel('plant length')
plt.ylabel('veg_dissip')
plt.show()

# %%
plt.plot(A[:,2],Output_dissip, 'ro')
plt.xlabel('plant diameter')
plt.ylabel('veg_dissip')
plt.show()

# %%
plt.plot(A[:,3],Output_dissip, 'ro')
plt.xlabel('plant thickness')
plt.ylabel('veg_dissip')
plt.show()

# %%
Output_wl = [0.086849769577, 0.071449350565, 0.081941329874, 0.0897887852043, 0.0852774027735, 0.0701932846569, 
             0.0821369960904, 0.0950508601964, 0.081545121036, 0.0934180691838, 0.071064000949, 0.083252047188, 
             0.070388467051, 0.0827063908, 0.082069950178]
